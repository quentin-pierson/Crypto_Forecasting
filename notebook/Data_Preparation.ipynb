# %% [markdown]
# # <center> Data_Prepration </center>

# %%
import pandas as pd 
from IPython.display import display

# %%
df = pd.read_csv("../data/train.csv")
df = df.set_index("timestamp")

# %%
display(df)
# Out:
#             Asset_ID  Count          Open          High           Low  \
# timestamp
# 1514764860         2   40.0   2376.580000   2399.500000   2357.140000
# 1514764860         0    5.0      8.530000      8.530000      8.530000
# 1514764860         1  229.0  13835.194000  14013.800000  13666.110000
# 1514764860         5   32.0      7.659600      7.659600      7.656700
# 1514764860         7    5.0     25.920000     25.920000     25.874000
# ...              ...    ...           ...           ...           ...
# 1632182400         9  775.0    157.181571    157.250000    156.700000
# 1632182400        10   34.0   2437.065067   2438.000000   2430.226900
# 1632182400        13  380.0      0.091390      0.091527      0.091260
# 1632182400        12  177.0      0.282168      0.282438      0.281842
# 1632182400        11   48.0    232.695000    232.800000    232.240000
#
#                    Close        Volume          VWAP    Target
# timestamp
# ...
